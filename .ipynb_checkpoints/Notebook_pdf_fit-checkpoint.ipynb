# %%
from cProfile import label
import os

import numpy as np
from scipy.stats import norm, lognorm
from scipy.integrate import trapezoid
from astropy.table import Table
from matplotlib import pyplot as plt
from iminuit import Minuit
from scipy.optimize._numdiff import approx_derivative
from scipy.interpolate import UnivariateSpline
from scipy.stats import norm, gamma
from scipy.stats import kstest
import argparse
from scipy.stats import levy_stable

# %% [markdown]
# # funictions

# %%
def plot_lightcurve(title, t, phi, ephi):
    fig, ax = plt.subplots(figsize=(10, 6), nrows=1, ncols = 1)
    plt.subplots_adjust(bottom = 0.1, top = 0.95, left=0.1, right=0.96, hspace=0.05)
    ax.set_title(title)
    ax.set_xlabel(r"Time [h]", ha="center", va = 'center', labelpad=12, fontsize=12)
    ax.set_ylabel(r"Energy flux [TeV cm$^{-2}$ s$^{-1}$]", ha="center", va = 'center', labelpad=12, fontsize=12)
    ax.set_yscale('log')
    ax.errorbar(t, phi, yerr = ephi, fmt='o',  mfc='none', color='k')
    #plt.savefig(f"{path}/Lightcurve.pdf", dpi=150)

# %%
def hist_flux(phi, ephi, rebin):
    #load the histogram
    phi_min, phi_max = np.min(phi-ephi), np.max(phi+ephi)
    phi_min = max(phi_min, 0.)
    
    valid = np.isfinite(phi) & np.isfinite(ephi) & (phi > 0)

    bin_size_log10 = np.nanmedian(
        ephi[valid] / (phi[valid] * np.log(10))
    ) * rebin
    print("Any NaN in phi?", np.isnan(phi).any())
    print("Any inf in phi?", np.isinf(phi).any())
    print("Min phi:", np.nanmin(phi))
    print("Max phi:", np.nanmax(phi))
    phi_min = np.min(phi[phi > 0])
    log10_phi_min, log10_phi_max = np.log10(phi_min), np.log10(phi_max) 
    print("rebin:", rebin)
    print("bin_size_log10:", bin_size_log10)
    #bins = np.arange(log10_phi_min, log10_phi_max+bin_size_log10, bin_size_log10)
    n_bins = max(1, int(np.ceil((log10_phi_max - log10_phi_min) / bin_size_log10)))

    bins = np.linspace(log10_phi_min,
                   log10_phi_max,
                   n_bins + 1)
    hist, bin_edges = np.histogram(np.log10(phi), bins=bins)

    return hist, bin_edges

def plot_histo(title, phi, ephi, pdf, rebin=1):
    hist, bins = hist_flux(phi, ephi, rebin)
    #plot
    fig, ax = plt.subplots(figsize=(8, 6), nrows=1, ncols = 1)
    plt.subplots_adjust(bottom = 0.1, top = 0.95, left=0.1, right=0.96, hspace=0.05)
    ax.set_title(title)
    ax.set_xlabel(r"log$_{10}$(energy flux [TeV cm$^{-2}$ s$^{-1}$])", ha="center", va = 'center', labelpad=12, fontsize=12)
    ax.set_ylabel(r"# entries", ha="center", va = 'center', labelpad=12, fontsize=12)
    #ax.set_yscale('log')
    log_phi = np.log10(phi)
    ax.stairs(hist,bins)
    bin_centers = 0.5*(bins[1:]+bins[:-1])
    sel = hist>=1
    ax.errorbar(bin_centers[sel], hist[sel], yerr = np.sqrt(hist[sel]), fmt='',  mfc='none', color='tab:blue', ls='none')

    bin_size_log10 = bins[1]-bins[0]
    log10phi_plot = np.linspace(np.min(log_phi), np.max(log_phi))
    phi_plot = np.power(10, log10phi_plot)
    normalization_pdf = phi.size*bin_size_log10*np.log(10)
    ax.plot(log10phi_plot, phi_plot*pdf(phi_plot)*normalization_pdf)
    plt.show()

def pdf_Gauss(x, mu, sigma):
    return norm(loc=mu, scale=sigma).pdf(x)

def pdf_LogNorm(x, mu, sigma):
    rv = lognorm(s=sigma, scale=np.exp(mu))
    return rv.pdf(x)

def pdf_gammaf(x, a, b):
    return gamma.pdf(x, a, scale=1/b)




def pdf_alpha_stable(x, loc, scale, alpha, beta=1.0):
    return levy_stable.pdf(x, alpha, beta, loc=loc, scale=scale)

MODELS = {
    "lognorm": {
        "pdf": lambda x, m, s: pdf_LogNorm(x, m, s),
        "names": ["mu", "sigma"]
    },
    "gaussian": {
        "pdf": lambda x, m, s: pdf_Gauss(x, m, s),
        "names": ["mean", "std"]
    },
    "alpha": {
        "pdf": lambda x, loc, scale: pdf_alpha_stable(x, alpha, loc, scale),
        "names": ["alpha", "loc", "scale"]
    }
}
def deviance(phi_i, ephi_i, pdf):

    #define the range of the integrand
    nsigma = 5

    #define the function to be integrated
    def integ(pdf_test, phi_0, ephi_0):
        #range for integration over the data uncertainties
        phi_int_min = np.min(phi_0 - nsigma*ephi_0)
        phi_int_max = np.max(phi_0 + nsigma*ephi_0)
        phi_integrand = np.linspace(phi_int_min, phi_int_max, 100)

        #integrand
        rv = norm(loc=phi_0,scale=ephi_0)
        integrand = rv.pdf(phi_integrand) * pdf_test(phi_integrand)
        return trapezoid(integrand, x=phi_integrand)

    #evaluate the integrand and its integral
    likelihood = np.array([integ(pdf, phi_i[i], ephi_i[i]) for i in range(phi_i.size)])
    lnL = np.sum(np.log(likelihood))

    #Saturated model - not sure it is the best one
    pdf_sat = lambda x: np.ones_like(x)
    likelihood_sat = np.array([integ(pdf_sat, phi_i[i], ephi_i[i]) for i in range(phi_i.size)])
    lnL_sat = np.sum(np.log(likelihood_sat))

    return -2*(lnL-lnL_sat)

def propagate_scipy_compatible(model, params, cov):
    """
    Computes output covariance via numerical Jacobian propagation.
    """
    params = np.asarray(params)
    cov = np.asarray(cov)

    y = model(params)
    J = approx_derivative(model, params, method="2-point")

    # Covariance propagation
    ycov = J @ cov @ J.T

    return y, ycov

def fitting(phi_i, ephi_i, init_mean, init_std, model="lognorm"):
    """
        Fits selected model on the data, giving best fit parameters and corresponding errors.
        Can be improved as the Gaussian fit is slow.
    """
    nsigma = 5
    if model not in MODELS:
        raise ValueError(f"Model '{model}' not supported. Choose from: {list(MODELS.keys())}")

    pdf_model = MODELS[model]["pdf"]
    param_names = MODELS[model]["names"]

    if model == "gaussian":
        def minimize_func(init_mean, init_std):
            var = init_std ** 2 + ephi_i ** 2
            logL_i = -0.5 * (np.log(2 * np.pi * var) + (phi_i - init_mean) ** 2 / var)

            return -np.sum(logL_i)

    elif model == "alpha":
        def minimize_func(alpha, loc, scale):
            pdf_vals = pdf_alpha_stable(phi_i, alpha, loc, scale)
            pdf_vals = np.clip(pdf_vals, 1e-300, None)
            return -np.sum(np.log(pdf_vals))

    else:
        def minimize_func(init_mean, init_std):
            # define the function to be integrated
            def integ(pdf_test, phi_0, ephi_0):
                # range for integration over the data uncertainties
                phi_int_min = np.min(phi_0 - nsigma * ephi_0)
                phi_int_max = np.max(phi_0 + nsigma * ephi_0)
                phi_integrand = np.linspace(phi_int_min, phi_int_max, 500)

                # integrand
                rv = norm(loc=phi_0, scale=ephi_0)
                integrand = rv.pdf(phi_integrand) *  pdf_test(phi_integrand, init_mean, init_std)
                return trapezoid(integrand, x=phi_integrand)

            likelihood = np.array([integ(pdf_model, phi_i[i], ephi_i[i]) for i in range(phi_i.size)])

            return -np.sum(np.log(likelihood))

    if model == "alpha":
        # choose sensible initial guesses
        init_alpha = 1.8
        init_loc = init_mean
        init_scale = init_std

        minuit = Minuit(minimize_func,
                        init_alpha, init_loc, init_scale,
                        name=param_names)
    else:
        minuit = Minuit(minimize_func,
                        init_mean, init_std,
                        name=param_names)



    if model == "alpha":
        minuit.limits[param_names[0]] = (0, 2) # alpha
        minuit.limits[param_names[1]] = (-5, 5)  # loc
        minuit.limits[param_names[2]] = (1e-3, 10)  # scale
    else:
        minuit.limits[param_names[1]] = (1e-6, 10)

    minuit.migrad()

    if not minuit.fmin.is_valid:
        print("Warning: Fit did not converge! Stopping iteration.")
    print("Fit new parameters:")
    for name in param_names:
        print(f"{name} = {minuit.values[name]}")

    if model == "alpha":
        yerr_prop = (np.nan, np.nan)
    else:
        y, ycov = propagate_scipy_compatible(
            lambda p: pdf_model(p, minuit.values[0], minuit.values[1]), minuit.values, minuit.covariance)
        yerr_prop = np.sqrt(np.diag(ycov))

    if model == "gaussian":
        dist = norm(loc=minuit.values[0], scale=minuit.values[1])
    elif model == "lognorm":
        dist = lognorm(s=minuit.values[1], scale=np.exp(minuit.values[0]))

    elif model == "alpha":
        dist = levy_stable( alpha =minuit.values[0], beta = 1.0, loc=minuit.values[1], scale=minuit.values[2] )

    best_params = [minuit.values[name] for name in param_names]
    logL = -minimize_func(*best_params)

    if model == "alpha":
        return (*best_params, np.nan, np.nan, logL)
    else:
        return minuit.values[0], minuit.values[1], yerr_prop[0], yerr_prop[1], logL

# %%
def fit_error_trend(flux, flux_err):
    """
        sigma_f^2 = C * flux
    Parameters
    ----------
    flux : array-like
        Observed flux values f_i.
    flux_err : array-like
        Observed errors sigma_{f_i}.

    Returns
    -------
    C : float
        Error scaling constant (1/(A*T)).
    """
    f = np.asarray(flux)
    s = np.asarray(flux_err)
    mask = f > 0
    f = f[mask]
    s = s[mask]
    C_values = (s**2) / f

    # Physical estimator: use the median
    C = np.median(C_values)

    return C
def simulate_distribution(flux, flux_err, flux_distribution_params, n_sim, model="gaussian", C=None):
    """
    Simulate n_sim light curves with flux-dependent errors following:

        sigma_f^2 = C * flux

    Parameters
    ----------
    n_sim : int
        Number of simulations (lightcurve realizations).
    flux_distribution_params
    model : str
        "gauss" or "lognorm".
    C : float
        Error scaling constant from _fit_error_trend().
        Required.

    Returns
    -------
    simulations : list of dict
        Each dict has:
            {"flux": array, "flux_err": array}
    """
    flux_distribution_params_dict = {"mean": flux_distribution_params[0], "std": flux_distribution_params[1]}
    if C is None:
        C = fit_error_trend(flux, flux_err)

    simulations = []
    npoints = len(flux)  # number of points in your lightcurve

    for _ in range(n_sim):

        # ----------------------------------------------------------
        # Step 1: Generate TRUE fluxes (one per data point)
        # ----------------------------------------------------------
        n = len(flux)  # match the real dataset size

        if model == "gaussian":
            mu = flux_distribution_params_dict['mean']
            sig = flux_distribution_params_dict['std']
            f_true = norm.rvs(loc=mu, scale=sig, size=n)

        elif model == "lognorm":
            mu = flux_distribution_params_dict['mean']
            sigma = flux_distribution_params_dict['std']
            f_true = lognorm.rvs(s=sigma, scale=np.exp(mu), size=n)
        elif model == "gamma":
            a = flux_distribution_params_dict['a']
            b = flux_distribution_params_dict['b']
            f_true = gamma.rvs(a = a, scale = 1/b, size =n)
        elif model == "alpha":
            print(flux_distribution_params)
            alpha = flux_distribution_params[0]
            loc = flux_distribution_params[1]
            scale = flux_distribution_params[2]
            f_true = levy_stable.rvs(loc = loc, scale=scale, alpha=alpha, beta=0.0, size = n)



        else:
            raise ValueError("model must be 'gauss' or 'lognorm'.")

        # No negative flux
        f_true = np.clip(f_true, 0, None)

        # ----------------------------------------------------------
        # Step 2: Compute physical measurement errors
        #          sigma_i^2 = C * f_true_i
        # ----------------------------------------------------------
        sigma = np.sqrt(C * f_true)

        # prevent sigma = 0 (causes likelihood collapse)
        sigma = np.clip(sigma, 1e-6, None)

        # ----------------------------------------------------------
        # Step 3: Generate measured fluxes
        # ----------------------------------------------------------
        f_meas = np.random.normal(f_true, sigma)

        # No negative measured flux
        f_meas = np.clip(f_meas, 0, None)

        simulations.append((f_meas, sigma))

    return simulations


def plot_likelihood_distribution(
        phi, ephi, t,
        fit_params,
        #path,
        model="gaussian",
        n_sim=100,
        title="Likelihood comparison"
):
    """
    Plot histogram of log-likelihoods from MC simulations and compare to real data.

    Parameters
    ----------
    phi, ephi : arrays
        Real flux and flux errors.
    fit_params : tuple
        Output of fitting() on real data:
        (mu, sigma, mu_err, sigma_err, logL_real)
    model : str
        "gaussian" or "lognorm"
    n_sim : int
        Number of MC simulations
    t : array
        Time array (only needed to get matching size)
    """

    print(f"\n### Likelihood comparison for model = {model} ###")

    mu_real, sigma_real = fit_params[0], fit_params[1]
    logL_real = fit_params[4]

    # -------------------------------------------------
    # 1) Generate simulations using best-fit parameters
    # -------------------------------------------------

    print(f"Generating {n_sim} simulations...")

    C = fit_error_trend(phi, ephi)
    sims = simulate_distribution(phi, ephi, fit_params,  n_sim=n_sim,  model=model, C=C)


    # -------------------------------------------------
    # 2) Fit each simulation and collect TS (logL)
    # -------------------------------------------------

    TS_sim = []
    print("Fitting simulations...")

    for i, (phi_sim, ephi_sim) in enumerate(sims):

        params_sim = fitting(
            phi_sim / np.median(phi_sim),
            ephi_sim / np.median(ephi_sim),
            mu_real, sigma_real,
            model=model
        )

        TS_sim.append(params_sim[4])

    TS_sim = np.array(TS_sim)
    print(TS_sim)

    # -------------------------------------------------
    # 3) Compute ΔTS and significance
    # -------------------------------------------------

    mean_sim = np.mean(TS_sim)
    std_sim = np.std(TS_sim)


    delta_TS = logL_real - mean_sim
    significance = delta_TS / std_sim if std_sim > 0 else np.nan
    z_score = delta_TS / std_sim
    print(f"Z-score (signed) = {z_score:.2f}")
    physical_sigma = np.abs(z_score)
    print(f"Significance level = {physical_sigma:.2f} σ")

    print(f"\nReal-data logL = {logL_real:.3f}")
    print(f"Sim mean logL  = {mean_sim:.3f}")
    print(f"Sim std logL   = {std_sim:.3f}")
    print(f"ΔTS = {delta_TS:.3f}")
    print(f"Significance = {significance:.2f} σ")
    TS_obs = logL_real
    p_value = np.mean(TS_sim >= TS_obs)
    print(f"p-value = {p_value}")
    # -------------------------------------------------
    # 4) Make the plot
    # -------------------------------------------------

    fig, ax = plt.subplots(figsize=(8, 6))
    ax.set_title(title + f" ({model})")
    ax.set_xlabel("Log-likelihood")
    ax.set_ylabel("Counts")

    # Histogram of sim log-likelihoods
    ax.hist(TS_sim, bins=20, alpha=0.7, color="tab:blue", label="Simulated TS")

    fit_mu, fit_std = norm.fit(TS_sim)

    x_vals = np.linspace(min(TS_sim), max(TS_sim), 300)
    pdf_vals = norm.pdf(x_vals, fit_mu, fit_std)

    hist_counts, bin_edges = np.histogram(TS_sim, bins=20)
    scale = max(hist_counts) / max(pdf_vals)
    pdf_vals *= scale

    ax.plot(
        x_vals, pdf_vals,
        color="black", linewidth=2,
        label=f"Gauss fit: μ={fit_mu:.2f}, σ={fit_std:.2f}"
    )
    # Vertical lines
    ax.axvline(mean_sim, color="blue", linestyle="--",
               label=f"Sim mean = {mean_sim:.2f}")

    ax.axvline(logL_real, color="red", linestyle="-",
               label=f"Real data = {logL_real:.2f}")

    ax.text(
        0.05, 0.95,
        fr"$\Delta TS = {delta_TS:.2f}$" + "\n" +
        fr"${abs(delta_TS/fit_std):.2f}\sigma$",
        transform=ax.transAxes,
        va="top", ha="left", fontsize=12,
        bbox=dict(facecolor="white", alpha=0.8)
    )

    plt.legend()
    plt.grid(alpha=0.3)
    #plt.show()
    #plt.savefig(f"{path}/Likelihood_distribution_{model}.pdf", dpi=150)

# -------------------------------------------------
# 5) Save results to file (minimal fix)
# -------------------------------------------------
    #outfile = f"{path}/likelihood_results_{model}.txt"
    # with open(outfile, "w") as f:
    #     f.write(f"Model: {model}\n")
    #     f.write(f"Real logL: {logL_real}\n")
    #     f.write(f"Mean sim logL: {mean_sim}\n")
    #     f.write(f"Std sim logL: {std_sim}\n")
    #     f.write(f"Delta TS: {delta_TS}\n")
    #     f.write(f"Significance: {significance} sigma\n")
    #     f.write("TS_sim array:\n")
    #     np.savetxt(f, TS_sim)


    return TS_sim, delta_TS, significance

# %% [markdown]
# # Analysis

# %%
name = "4FGL_J1800.6+7828"
index = 6
filename = f"/home/amikhno/local/src/CTAegal/LightCurves_Julian/{index}_{name}/{index}_LC_{name}_ZTF.csv"
data = Table.read(filename, format="ascii.csv")
t = data["mjd"]
phi = data["std_flux"]
ephi = data["std_flux_error"]
data
# Out:
# <Table length=1682>
#     mjd          std_flux        std_flux_error
#   float64        float64            float64
# ----------- ------------------ ------------------
#  58197.3417  0.905211928527144 0.0103959064874302
#  58197.3597 0.8797584933425576 0.0101371592971208
# 58197.39017 0.9071616208002232 0.0104157737667895
# 58197.41316 0.9143116811045836 0.0104886852147422
#  58198.3659 0.8374480357904155 0.0097096327748591
# 58198.39106 0.8461463166883393 0.0097972572690439
#  58198.4036 0.8488721165837181 0.0098247423894138
# 58202.28658 1.1146984252515204 0.0144146925680523
# 58202.30551 1.0921738842434772 0.0141764718408378
#         ...                ...                ...
# 60595.17984 0.6830917941691483 0.0081798773467248
# 60597.14083 0.7386798771389317 0.0087250407075457
# 60597.17892 0.7457653267104857 0.0106405393167661
# 60599.15924 0.7183244818893071 0.0085246202357285
# 60603.13892 0.6990969181108613 0.0101854154650831
# 60603.18266 0.6972425270953553 0.0083180000778236
#  60607.1364 0.7162545397084717  0.010352065842395
# 60607.16009 0.6987339871141359 0.0083325878069645
# 60609.11524  0.698745441431313 0.0101820108427427
# 60609.16257 0.7166215570949326 0.0085078925694889

# %%
filename = f"/home/amikhno/Downloads/4FGL_J1800.6+7828_weekly_3_3_2026.csv"
data = Table.read(filename, format="ascii.csv")
phi_raw = data["Photon Flux [0.1-100 GeV](photons cm-2 s-1)"]
ephi_raw = data["Photon Flux Error(photons cm-2 s-1)"]
t = np.array(data["Julian Date"], dtype=float)

phi = []
ephi = []
upper_limit_mask = []

for val in phi_raw:
    val = val.strip()
    
    if val.startswith("<"):
        upper_limit_mask.append(True)
        val = val.replace("<", "").strip()
    else:
        upper_limit_mask.append(False)
        
    phi.append(float(val))

phi = np.array(phi)
upper_limit_mask = np.array(upper_limit_mask)

ephi = np.array([
    float(v) if v.strip() not in ["", "-"] else np.nan
    for v in ephi_raw
])

# %%
title = f"{name} - FermiLAT data"
#Plot the initial lightcurve as it is
phi_med = np.median(phi)
plot_lightcurve(title, t, phi, ephi)

# %%
mean, std = 0.06, 0.54
params_fited_ln = fitting(phi / phi_med, ephi / phi_med, mean , std )
print(f" Lognormal fit parameters: {params_fited_ln}")
mean, std = 1.3, 0.99
params_fited_norm = fitting(phi / phi_med, ephi / phi_med, mean, std,  model="gaussian")
print(f" Gaussian fit parameters: {params_fited_norm}")
mean, std = 0.25, 1.2
params_fited_alpha = fitting(phi / phi_med, ephi / phi_med, mean, std, model="alpha")
print(f" Alpha fit parameters: {params_fited_alpha}")
# Out:
# /tmp/ipykernel_218231/1299511206.py:149: RuntimeWarning: divide by zero encountered in log
#   return -np.sum(np.log(likelihood))
# Warning: Fit did not converge! Stopping iteration.
# Fit new parameters:
# mu = 0.06
# sigma = 0.5399999999999999
#  Lognormal fit parameters: (0.06, 0.5399999999999999, np.float64(nan), np.float64(nan), np.float64(nan))
# Warning: Fit did not converge! Stopping iteration.
# Fit new parameters:
# mean = 1.3
# std = 0.9899999999999999
#  Gaussian fit parameters: (1.3, 0.9899999999999999, np.float64(nan), np.float64(nan), np.float64(nan))
# Fit new parameters:
# alpha = 1.9999997495677577
# loc = 0.3182350041069607
# scale = 1.1682708247792426
#  Alpha fit parameters: (1.9999997495677577, 0.3182350041069607, 1.1682708247792426, nan, nan, np.float64(-1058.5780002029499))

# %%
   #Plot the initinal data vs the fited dist

hist, bins = hist_flux(phi/ phi_med,  ephi/ phi_med, 1)


#  plot
fig, ax = plt.subplots(figsize=(8, 6), nrows=1, ncols=1)
plt.subplots_adjust(bottom=0.1, top=0.95, left=0.1, right=0.96, hspace=0.05)
ax.set_title(title)
ax.set_xlabel(r"log$_{10}$(energy flux [TeV cm$^{-2}$ s$^{-1}$])", ha="center", va='center', labelpad=12,
              fontsize=12)
ax.set_ylabel(r"# entries", ha="center", va='center', labelpad=12, fontsize=12)
# ax.set_yscale('log')
log_phi = np.log10(phi / phi_med)
ax.stairs(hist, bins)
bin_centers = 0.5 * (bins[1:] + bins[:-1])
sel = hist >= 1
ax.errorbar(bin_centers[sel], hist[sel], yerr=np.sqrt(hist[sel]), fmt='', mfc='none', color='tab:blue', ls='none')

bin_size_log10 = bins[1] - bins[0]
log10phi_plot = np.linspace(np.min(log_phi), np.max(log_phi))
phi_plot = np.power(10, log10phi_plot)
normalization_pdf = phi.size * bin_size_log10 * np.log(10)
# pdf_ln = lambda x: pdf_LogNorm(x, 0.06,0.54)
# label_lognorm = (
#     "Lognormal fit\n"
#     fr"$\mu = {0.06}\pm {0.0}$, "
#     fr"$\sigma = {0.54} \pm {0.05}$"
# )
# ax.plot(log10phi_plot, phi_plot * pdf_ln(phi_plot) * normalization_pdf, label=label_lognorm)

# pdf_norm = lambda x: pdf_Gauss(x, 1.27, 0.98)
# label_norm = ("Gaussian fit\n"
#     fr"$\mu = {1.27} \pm {0.0}$, "
#     fr"$\sigma = {0.98} \pm {0.01}$")
# ax.plot(log10phi_plot, phi_plot * pdf_norm(phi_plot) * normalization_pdf, label=label_norm)

# pdf_Alpha= lambda x: pdf_alpha_stable(x,1.85, 0.25, 1.16)
# label_alpha = (
#     "Alpha-stable fit\n"
#     fr"$\mathrm{{alpha}} = {1.85}$,"
#     fr"$\mathrm{{loc}} = {0.25}$, "
#     fr"$\mathrm{{scale}} =  {1.16}$"
# )



pdf_ln = lambda x: pdf_LogNorm(x, params_fited_ln[0], params_fited_ln[1])
label_lognorm = (
    "Lognormal fit\n"
    fr"$\mu = {params_fited_ln[0]:.2f} \pm {params_fited_ln[2]:.2f}$, "
    fr"$\sigma = {params_fited_ln[1]:.2f} \pm {params_fited_ln[3]:.2f}$"
)
ax.plot(log10phi_plot, phi_plot * pdf_ln(phi_plot) * normalization_pdf, label=label_lognorm)

pdf_norm = lambda x: pdf_Gauss(x, params_fited_norm[0], params_fited_norm[1])
label_norm = (
    "Gaussian fit\n"
    fr"$\mu = {params_fited_norm[0]:.2f} \pm {params_fited_norm[2]:.2f}$, "
    fr"$\sigma = {params_fited_norm[1]:.2f} \pm {params_fited_norm[3]:.2f}$"
)
ax.plot(log10phi_plot, phi_plot * pdf_norm(phi_plot) * normalization_pdf, label=label_norm)

pdf_Alpha= lambda x: pdf_alpha_stable(x, params_fited_alpha[0], params_fited_alpha[1], params_fited_alpha[2])
label_alpha = (
    "Alpha-stable fit\n"
    fr"$\mathrm{{alpha}} = {params_fited_alpha[0]:.2f}$,"
    fr"$\mathrm{{loc}} = {params_fited_alpha[1]:.2f}$, "
    fr"$\mathrm{{scale}} = {params_fited_alpha[2]:.2f}$"
)



ax.plot(log10phi_plot, phi_plot * pdf_Alpha(phi_plot) * normalization_pdf, label=label_alpha)

plt.legend()
# Out:
# Any NaN in phi? False
# Any inf in phi? False
# Min phi: 0.1906005221932115
# Max phi: 74.80417754569191
# rebin: 1
# bin_size_log10: 0.11317977407175651
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 3
#       1 #Plot the initinal data vs the fited dist
# ----> 3 hist, bins = hist_flux(phi/ phi_med,  ephi/ phi_med, 1)
#       6 #  plot
#       7 fig, ax = plt.subplots(figsize=(8, 6), nrows=1, ncols=1)
#
# Cell In[58], line 20, in hist_flux(phi, ephi, rebin)
#      18 print("bin_size_log10:", bin_size_log10)
#      19 #bins = np.arange(log10_phi_min, log10_phi_max+bin_size_log10, bin_size_log10)
# ---> 20 n_bins = max(1, int(np.ceil((log10_phi_max - log10_phi_min) / bin_size_log10)))
#      22 bins = np.linspace(log10_phi_min,
#      23                log10_phi_max,
#      24                n_bins + 1)
#      25 hist, bin_edges = np.histogram(np.log10(phi), bins=bins)
#
# ValueError: cannot convert float NaN to integer

# %%
print("Perform the simulations and the fit for Gaussian")
params_fited_norm = fitting(phi / phi_med, ephi / phi_med, 0.1, 1.5, model="gaussian")

plot_likelihood_distribution(
    phi=phi,
    ephi=ephi,
    t=t,
    fit_params=params_fited_norm,
    model="gaussian",
    n_sim=10,
    title="Gaussian Model Likelihood Test"
)
# Out:
# Perform the simulations and the fit for Gaussian
# Fit new parameters: mean = 1.0387672871405365, std = 0.2845632506332393
#
# ### Likelihood comparison for model = gaussian ###
# Generating 10 simulations...
# Fitting simulations...
# Fit new parameters: mean = 0.8982073020626432, std = 0.0001341272308534751
# Fit new parameters: mean = 0.8982422015929626, std = 0.1369895666059432
# Fit new parameters: mean = 0.8883839820137973, std = 0.10364381491962828
# Fit new parameters: mean = 0.8928062714837536, std = 0.1385658725482505
# Fit new parameters: mean = 0.9085727126340489, std = 0.0001253370587038023
# Fit new parameters: mean = 0.9080102511466185, std = 0.0001302669943087966
# Fit new parameters: mean = 0.8961114172294831, std = 0.1367954986717592
# Fit new parameters: mean = 0.906834700813169, std = 0.00013793649199186399
# Fit new parameters: mean = 0.9031580319588383, std = 0.0001504215670791477
# Fit new parameters: mean = 0.8943771060542346, std = 0.13571469985626003
# [-2284.08404142 -2337.73283864 -2326.28599296 -2345.9705618
#  -2286.38443273 -2288.01152134 -2328.32286408 -2284.04210021
#  -2297.62463485 -2324.03718253]
# Z-score (signed) = 82.34
# Significance level = 82.34 σ
#
# Real-data logL = -396.751
# Sim mean logL  = -2310.250
# Sim std logL   = 23.238
# ΔTS = 1913.499
# Significance = 82.34 σ
# p-value = 0.0
# (array([-2284.08404142, -2337.73283864, -2326.28599296, -2345.9705618 ,
#         -2286.38443273, -2288.01152134, -2328.32286408, -2284.04210021,
#         -2297.62463485, -2324.03718253]),
#  np.float64(1913.498764055088),
#  np.float64(82.34266136829996))

# %%
print("Perform the simulations and the fit for Lognormal")

params_fited_norm = fitting(phi / phi_med, ephi / phi_med, 0.1, 1.5, model="lognorm")

plot_likelihood_distribution(
    phi=phi,
    ephi=ephi,
    t=t,
    fit_params=params_fited_norm,
    model="lognorm",
    n_sim=10,
    title="Lognorm Model Likelihood Test"
)
# Out:
# Perform the simulations and the fit for Lognormal
# Fit new parameters: mean = 0.0018599839741402558, std = 0.26864756574146914
#
# ### Likelihood comparison for model = lognorm ###
# Generating 10 simulations...
# Fitting simulations...
# Fit new parameters: mean = -0.038493795152161815, std = 0.010288020423130711
# /tmp/ipykernel_16326/1727027901.py:148: RuntimeWarning: divide by zero encountered in log
#   return -np.sum(np.log(likelihood))
# Fit new parameters: mean = -0.03681038057649189, std = 0.010113152550731565
# Fit new parameters: mean = -0.03593215647474437, std = 0.010197766152219552
# Fit new parameters: mean = -0.05012402615580334, std = 0.010836574949244063
# Fit new parameters: mean = -0.022055185483775913, std = 0.010416965480821062
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[55], line 5
#       1 print("Perform the simulations and the fit for Lognormal")
#       3 params_fited_norm = fitting(phi / phi_med, ephi / phi_med, 0.1, 1.5, model="lognorm")
# ----> 5 plot_likelihood_distribution(
#       6     phi=phi,
#       7     ephi=ephi,
#       8     t=t,
#       9     fit_params=params_fited_norm,
#      10     model="lognorm",
#      11     n_sim=10,
#      12     title="Lognorm Model Likelihood Test"
#      13 )
#
# Cell In[26], line 163, in plot_likelihood_distribution(phi, ephi, t, fit_params, model, n_sim, title)
#     159 print("Fitting simulations...")
#     161 for i, (phi_sim, ephi_sim) in enumerate(sims):
# --> 163     params_sim = fitting(
#     164         phi_sim / np.median(phi_sim),
#     165         ephi_sim / np.median(ephi_sim),
#     166         mu_real, sigma_real,
#     167         model=model
#     168     )
#     170     TS_sim.append(params_sim[4])
#     172 TS_sim = np.array(TS_sim)
#
# Cell In[19], line 161, in fitting(phi_i, ephi_i, init_mean, init_std, model)
#     158 else:
#     159     minuit.limits[param_names[1]] = (1e-6, 10)
# --> 161 minuit.migrad()
#     163 if not minuit.fmin.is_valid:
#     164     print("Warning: Fit did not converge! Stopping iteration.")
#
# File ~/local/opt/conda/envs/gammapy-1.3/lib/python3.11/site-packages/iminuit/minuit.py:789, in Minuit.migrad(self, ncall, iterate, use_simplex)
#     787 t = mutil._Timer(self._fmin)
#     788 with t:
# --> 789     fm = _robust_low_level_fit(
#     790         self._fcn,
#     791         self._last_state,
#     792         replace_none(ncall, 0),
#     793         self._strategy,
#     794         self._tolerance,
#     795         self._precision,
#     796         iterate,
#     797         use_simplex,
#     798     )
#     800 self._last_state = fm.state
#     802 self._fmin = mutil.FMin(
#     803     fm,
#     804     "Migrad",
#    (...)
#     809     t.value,
#     810 )
#
# File ~/local/opt/conda/envs/gammapy-1.3/lib/python3.11/site-packages/iminuit/minuit.py:2745, in _robust_low_level_fit(fcn, state, ncall, strategy, tolerance, precision, iterate, use_simplex)
#    2743 if precision is not None:
#    2744     migrad.precision = precision
# -> 2745 fm = migrad(ncall, tolerance)
#    2746 strategy = MnStrategy(2)
#    2747 migrad = MnMigrad(fcn, fm.state, strategy)
#
# Cell In[19], line 146, in fitting.<locals>.minimize_func(init_mean, init_std)
#     143     integrand = rv.pdf(phi_integrand) *  pdf_test(phi_integrand, init_mean, init_std)
#     144     return trapezoid(integrand, x=phi_integrand)
# --> 146 likelihood = np.array([integ(pdf_model, phi_i[i], ephi_i[i]) for i in range(phi_i.size)])
#     148 return -np.sum(np.log(likelihood))
#
# Cell In[19], line 146, in <listcomp>(.0)
#     143     integrand = rv.pdf(phi_integrand) *  pdf_test(phi_integrand, init_mean, init_std)
#     144     return trapezoid(integrand, x=phi_integrand)
# --> 146 likelihood = np.array([integ(pdf_model, phi_i[i], ephi_i[i]) for i in range(phi_i.size)])
#     148 return -np.sum(np.log(likelihood))
#
# Cell In[19], line 143, in fitting.<locals>.minimize_func.<locals>.integ(pdf_test, phi_0, ephi_0)
#     141 # integrand
#     142 rv = norm(loc=phi_0, scale=ephi_0)
# --> 143 integrand = rv.pdf(phi_integrand) *  pdf_test(phi_integrand, init_mean, init_std)
#     144 return trapezoid(integrand, x=phi_integrand)
#
# Cell In[19], line 51, in <lambda>(x, m, s)
#      46 def pdf_alpha_stable(x, loc, scale, alpha=1.8, beta=0.0):
#      47     return levy_stable.pdf(x, alpha, beta, loc=loc, scale=scale)
#      49 MODELS = {
#      50     "lognorm": {
# ---> 51         "pdf": lambda x, m, s: pdf_LogNorm(x, m, s),
#      52         "names": ["mu", "sigma"]
#      53     },
#      54     "gaussian": {
#      55         "pdf": lambda x, m, s: pdf_Gauss(x, m, s),
#      56         "names": ["mean", "std"]
#      57     },
#      58     "alpha": {
#      59         "pdf": lambda x, loc, scale: pdf_alpha_stable(x, loc, scale),
#      60         "names": ["loc", "scale"]
#      61     }
#      62 }
#      64 def deviance(phi_i, ephi_i, pdf):
#      65
#      66     #define the range of the integrand
#      67     nsigma = 5
#
# Cell In[19], line 39, in pdf_LogNorm(x, mu, sigma)
#      38 def pdf_LogNorm(x, mu, sigma):
# ---> 39     rv = lognorm(s=sigma, scale=np.exp(mu))
#      40     return rv.pdf(x)
#
# File ~/local/opt/conda/envs/gammapy-1.3/lib/python3.11/site-packages/scipy/stats/_distn_infrastructure.py:890, in rv_generic.__call__(self, *args, **kwds)
#     889 def __call__(self, *args, **kwds):
# --> 890     return self.freeze(*args, **kwds)
#
# File ~/local/opt/conda/envs/gammapy-1.3/lib/python3.11/site-packages/scipy/stats/_distn_infrastructure.py:885, in rv_generic.freeze(self, *args, **kwds)
#     870 """Freeze the distribution for the given arguments.
#     871
#     872 Parameters
#    (...)
#     882
#     883 """
#     884 if isinstance(self, rv_continuous):
# --> 885     return rv_continuous_frozen(self, *args, **kwds)
#     886 else:
#     887     return rv_discrete_frozen(self, *args, **kwds)
#
# File ~/local/opt/conda/envs/gammapy-1.3/lib/python3.11/site-packages/scipy/stats/_distn_infrastructure.py:504, in rv_frozen.__init__(self, dist, *args, **kwds)
#     501 self.kwds = kwds
#     503 # create a new instance
# --> 504 self.dist = dist.__class__(**dist._updated_ctor_param())
#     506 shapes, _, _ = self.dist._parse_args(*args, **kwds)
#     507 self.a, self.b = self.dist._get_support(*shapes)
#
# File ~/local/opt/conda/envs/gammapy-1.3/lib/python3.11/site-packages/scipy/stats/_distn_infrastructure.py:1845, in rv_continuous.__init__(self, momtype, a, b, xtol, badvalue, name, longname, shapes, seed)
#    1841 def __init__(self, momtype=1, a=None, b=None, xtol=1e-14,
#    1842              badvalue=None, name=None, longname=None,
#    1843              shapes=None, seed=None):
# -> 1845     super().__init__(seed)
#    1847     # save the ctor parameters, cf generic freeze
#    1848     self._ctor_param = dict(
#    1849         momtype=momtype, a=a, b=b, xtol=xtol,
#    1850         badvalue=badvalue, name=name, longname=longname,
#    1851         shapes=shapes, seed=seed)
#
# File ~/local/opt/conda/envs/gammapy-1.3/lib/python3.11/site-packages/scipy/stats/_distn_infrastructure.py:678, in rv_generic.__init__(self, seed)
#     675 super().__init__()
#     677 # figure out if _stats signature has 'moments' keyword
# --> 678 sig = _getfullargspec(self._stats)
#     679 self._stats_has_moments = ((sig.varkw is not None) or
#     680                            ('moments' in sig.args) or
#     681                            ('moments' in sig.kwonlyargs))
#     682 self._random_state = check_random_state(seed)
#
# File ~/local/opt/conda/envs/gammapy-1.3/lib/python3.11/site-packages/scipy/_lib/_util.py:398, in getfullargspec_no_self(func)
#     377 def getfullargspec_no_self(func):
#     378     """inspect.getfullargspec replacement using inspect.signature.
#     379
#     380     If func is a bound method, do not list the 'self' parameter.
#    (...)
#     396
#     397     """
# --> 398     sig = inspect.signature(func)
#     399     args = [
#     400         p.name for p in sig.parameters.values()
#     401         if p.kind in [inspect.Parameter.POSITIONAL_OR_KEYWORD,
#     402                       inspect.Parameter.POSITIONAL_ONLY]
#     403     ]
#     404     varargs = [
#     405         p.name for p in sig.parameters.values()
#     406         if p.kind == inspect.Parameter.VAR_POSITIONAL
#     407     ]
#
# File ~/local/opt/conda/envs/gammapy-1.3/lib/python3.11/inspect.py:3263, in signature(obj, follow_wrapped, globals, locals, eval_str)
#    3261 def signature(obj, *, follow_wrapped=True, globals=None, locals=None, eval_str=False):
#    3262     """Get a signature object for the passed callable."""
# -> 3263     return Signature.from_callable(obj, follow_wrapped=follow_wrapped,
#    3264                                    globals=globals, locals=locals, eval_str=eval_str)
#
# File ~/local/opt/conda/envs/gammapy-1.3/lib/python3.11/inspect.py:3011, in Signature.from_callable(cls, obj, follow_wrapped, globals, locals, eval_str)
#    3007 @classmethod
#    3008 def from_callable(cls, obj, *,
#    3009                   follow_wrapped=True, globals=None, locals=None, eval_str=False):
#    3010     """Constructs Signature for the given callable object."""
# -> 3011     return _signature_from_callable(obj, sigcls=cls,
#    3012                                     follow_wrapper_chains=follow_wrapped,
#    3013                                     globals=globals, locals=locals, eval_str=eval_str)
#
# File ~/local/opt/conda/envs/gammapy-1.3/lib/python3.11/inspect.py:2464, in _signature_from_callable(obj, follow_wrapper_chains, skip_bound_arg, globals, locals, eval_str, sigcls)
#    2461 sig = _get_signature_of(obj.__func__)
#    2463 if skip_bound_arg:
# -> 2464     return _signature_bound_method(sig)
#    2465 else:
#    2466     return sig
#
# File ~/local/opt/conda/envs/gammapy-1.3/lib/python3.11/inspect.py:2042, in _signature_bound_method(sig)
#    2037 def _signature_bound_method(sig):
#    2038     """Private helper to transform signatures for unbound
#    2039     functions to bound methods.
#    2040     """
# -> 2042     params = tuple(sig.parameters.values())
#    2044     if not params or params[0].kind in (_VAR_KEYWORD, _KEYWORD_ONLY):
#    2045         raise ValueError('invalid method signature')
#
# KeyboardInterrupt:

# %%
print("Perform the simulations and the fit for Alpha-stable")

params_fited_norm = fitting(phi / phi_med, ephi / phi_med, 0.1, 1.5, model="alpha")

plot_likelihood_distribution(
    phi=phi,
    ephi=ephi,
    t=t,
    fit_params=params_fited_alpha,
    model="alpha",
    n_sim=10,
    title="Alpha model Likelihood Test"
)
